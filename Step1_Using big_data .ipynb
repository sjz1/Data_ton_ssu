# %% [markdown]
# # 데이터 가져오기

# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
import pandas as pd

colors = ["black", "silver","rosybrown","brown","red","chocolate","darkorange","tan","darkgoldenrod","gold","olive","yellow","yellowgreen","darkseagreen","lightgreen","forestgreen", "springgreen","aqua", "deepskyblue","navy", "blue", "slateblue","rebeccapurple" ,"black", "silver","rosybrown","brown","red","chocolate","darkorange","tan","darkgoldenrod","gold","olive","yellow","yellowgreen","darkseagreen","lightgreen","forestgreen", "springgreen","aqua", "deepskyblue","navy", "blue", "slateblue","rebeccapurple" , "black", "silver","rosybrown","brown","red","chocolate","darkorange","tan","darkgoldenrod","gold","olive","yellow","yellowgreen","darkseagreen","lightgreen","forestgreen", "springgreen","aqua", "deepskyblue","navy", "blue", "slateblue","rebeccapurple" , "black", "silver","rosybrown","brown","red","chocolate","darkorange","tan","darkgoldenrod","gold","olive","yellow","yellowgreen","darkseagreen","lightgreen","forestgreen", "springgreen","aqua", "deepskyblue","navy", "blue", "slateblue","rebeccapurple" , "black", "silver","rosybrown","brown","red","chocolate","darkorange","tan","darkgoldenrod","gold","olive","yellow","yellowgreen","darkseagreen","lightgreen","forestgreen", "springgreen","aqua", "deepskyblue","navy", "blue", "slateblue","rebeccapurple" , "black", "silver","rosybrown","brown","red","chocolate","darkorange","tan", "darkgoldenrod","gold","olive","yellow","yellowgreen","darkseagreen","lightgreen","forestgreen", "springgreen","aqua", "deepskyblue","navy", "blue", "slateblue","rebeccapurple" , "black", "silver","rosybrown","brown","red","chocolate","darkorange","tan", "darkgoldenrod","gold","olive","yellow","yellowgreen","darkseagreen","lightgreen","forestgreen", "springgreen","aqua", "deepskyblue","navy", "blue", "slateblue","rebeccapurple" , "black", "silver","rosybrown","brown","red","chocolate","darkorange","tan","darkgoldenrod","gold","olive","yellow","yellowgreen","darkseagreen","lightgreen","forestgreen", "springgreen","aqua", "deepskyblue","navy", "blue", "slateblue","rebeccapurple" , "black", "silver","rosybrown","brown","red","chocolate"]
# 한글 폰트 사용을 위해서 세팅

import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

#from matplotlib import font_manager, rc
#font_path = "./SoulTitle.ttf"
#font = font_manager.FontProperties(fname=font_path).get_name()
#rc('font', family=font)

# %% [markdown]
# ### 도서관 출입 데이터 가져오기

# %%
lib_in = pd.read_csv("./actual_practice/데이터2022/데이터_도서관출입.csv", encoding = 'cp949') 
#-> 0번째 행을 index로 사용하겠다 열을 가지고 싶으면 index_row=0)
# encoding ->  'cp949' :한글 파일도 가져옴
print(lib_in.info())
print('-----------------------------------------------------------------------------------------')
lib_in = lib_in.dropna(how='any') #-> NA하나라도 있으면 지움
print(lib_in.info())

#Errow -> column에 NaN 이 있거나 여러타입이 섞여 있으면 다음과 같이 나온다
#해결 방법 csv 읽을때  low_memory=False 추가
#C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165:
#DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#  has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7964251 entries, 0 to 7964250
# Data columns (total 6 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   출입일시    object
#  1   출입구     object
#  2   연출입건수   int64
#  3   입학년도    int64
#  4   소속      object
#  5   상위소속    object
# dtypes: int64(2), object(4)
# memory usage: 364.6+ MB
# None
# -----------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7963865 entries, 0 to 7964250
# Data columns (total 6 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   출입일시    object
#  1   출입구     object
#  2   연출입건수   int64
#  3   입학년도    int64
#  4   소속      object
#  5   상위소속    object
# dtypes: int64(2), object(4)
# memory usage: 425.3+ MB
# None

# %%
lib_in.head()
# Out:
#                   출입일시 출입구  연출입건수  입학년도        소속    상위소속
# 0  2017/03/02 10:18:35  입구    284  2012   글로벌통상학과  경제통상대학
# 1  2017/03/02 10:18:43  입구    278  2015  벤처중소기업학과    경영대학
# 2  2017/03/02 10:18:45  출구    694  2012      회계학과    경영대학
# 3  2017/03/02 10:18:45  입구    121  2016  의생명시스템학부  자연과학대학
# 4  2017/03/02 10:18:48  입구    310  2016  의생명시스템학부  자연과학대학

# %% [markdown]
# ### 단행본 대출 데이터 가져오기

# %%
lib_bro = pd.read_csv("./actual_practice/데이터2022/데이터_단행본대출.csv", encoding = 'cp949',low_memory=False) 
#-> 0번째 행을 index로 사용하겠다 열을 가지고 싶으면 index_row=0)
# encoding ->  'cp949' :한글 파일도 가져옴
print(lib_bro.info())
print('-----------------------------------------------------------------------------------------')
lib_bro = lib_bro.dropna(how='any') #-> NA하나라도 있으면 지움
print(lib_bro.info())

#Errow -> column에 NaN 이 있거나 여러타입이 섞여 있으면 다음과 같이 나온다
#해결 방법 csv 읽을때  low_memory=False 추가
#C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165:
#DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#  has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581952 entries, 0 to 581951
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   대출일시    581952 non-null  object
#  1   반납일시    581670 non-null  object
#  2   등록번호    581952 non-null  object
#  3   ISBN    577339 non-null  object
#  4   서명      581952 non-null  object
#  5   대출연장구분  581952 non-null  object
#  6   연대출권수   581952 non-null  int64
#  7   입학년도    581952 non-null  int64
#  8   소속      581952 non-null  object
#  9   상위소속    581555 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 44.4+ MB
# None
# -----------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 576698 entries, 30 to 581951
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   대출일시    576698 non-null  object
# ...

# %%
lib_bro.head()
# Out:
#                    대출일시                 반납일시     등록번호           ISBN  \
# 30  2017/03/02 07:00:59  2017/03/08 00:00:00  E611752  9788969940001
# 31  2017/03/02 07:01:03  2017/03/08 00:00:00  E684800  9788937473005
# 32  2017/03/02 01:02:43  2017/03/16 00:00:00  E709617  9788996937432
# 33  2017/03/02 01:02:27  2017/03/16 00:00:00  E714987  9788960863101
# 34  2017/03/02 01:02:32  2017/03/02 00:00:00  E637233  9788970551234
#
#                                        서명 대출연장구분  연대출권수  입학년도      소속    상위소속
# 30  해뜨기 전이 가장 어둡다 :폐허의 철학자 에밀 시오랑의 절망의 팡세     연장    130  2012     철학과    인문대학
# 31          주말, 출근, 산책 : 어두움과 비 :김엄지 장편소설     연장    130  2012     철학과    인문대학
# 32                         자본주의 사회주의 민주주의     연장     90  2014  금융경제학과  경제통상대학
# 33                   메시 :혼돈에서 탄생화는 극적인 결과     연장     90  2014  금융경제학과  경제통상대학
# 34                                소유냐 삶이냐     연장     90  2014  금융경제학과  경제통상대학

# %% [markdown]
# # 전처리

# %%
#필요없는 칼럼 제거
lib_in = lib_in.drop([lib_in.columns[0],lib_in.columns[1],lib_in.columns[5]], axis= 1)
lib_bro = lib_bro.drop([lib_bro.columns[0],lib_bro.columns[1],lib_bro.columns[2],lib_bro.columns[3],lib_bro.columns[4],lib_bro.columns[5],lib_bro.columns[9]], axis= 1)

# %%
# 중복되는 데이터 지우기
# 가정 (year_borrow admission_year,department) -> primary_key
primary_lib_in =lib_in.drop_duplicates(['연출입건수' ,'입학년도','소속'])
primary_lib_bro =lib_bro.drop_duplicates(['연대출권수' ,'입학년도','소속'])

# %%
primary_lib_in.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41900 entries, 0 to 7959899
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연출입건수   41900 non-null  int64
#  1   입학년도    41900 non-null  int64
#  2   소속      41900 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 1.3+ MB

# %%
primary_lib_bro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14158 entries, 30 to 581939
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연대출권수   14158 non-null  int64
#  1   입학년도    14158 non-null  int64
#  2   소속      14158 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 442.4+ KB

# %% [markdown]
# # 입학년도 2000~2021 년만 살리고 Cut

# %%
primary_lib_in =primary_lib_in[2021>=primary_lib_in.입학년도]
primary_lib_in =primary_lib_in[primary_lib_in.입학년도>=2000]
primary_lib_bro =primary_lib_bro[2021>=primary_lib_bro.입학년도]
primary_lib_bro =primary_lib_bro[primary_lib_bro.입학년도>=2000]
primary_lib_in.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41576 entries, 0 to 7959899
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연출입건수   41576 non-null  int64
#  1   입학년도    41576 non-null  int64
#  2   소속      41576 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 1.3+ MB

# %%
primary_lib_bro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14109 entries, 30 to 581939
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연대출권수   14109 non-null  int64
#  1   입학년도    14109 non-null  int64
#  2   소속      14109 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 440.9+ KB

# %% [markdown]
# # 데이터추출

# %% [markdown]
# 먼저 학과 이름을 모두 뽑아보자

# %%
temp_count1 =lib_in.drop_duplicates(['입학년도','소속'])
temp_count1 = temp_count1[2021>=temp_count1.입학년도]
temp_count1 = temp_count1[temp_count1.입학년도>=2000]
idx_name= temp_count1.drop_duplicates(['소속'])
idx_name= idx_name['소속']
idx_name.index = np.arange(len(idx_name))
department_name = idx_name
department_name
# Out:
# 0            글로벌통상학과
# 1           벤처중소기업학과
# 2               회계학과
# 3           의생명시스템학부
# 4             사회복지학부
# 5        산업·정보시스템공학과
# 6                화학과
# 7               금융학부
# 8          정보통신전자공학부
# 9               경영학부
# 10            중어중문학과
# 11    전자정보공학부 IT융합전공
# 12             전기공학부
# 13              행정학부
# 14             화학공학과
# 15             기계공학부
# 16    전자정보공학부 전자공학전공
# 17            정치외교학과
# 18             기독교학과
# 19              건축학부
# 20            국제법무학과
# 21            영어영문학과
# 22            언론홍보학과
# 23               법학과
# 24            정보사회학과
# 25              경제학과
# 26            AI융합학부
# 27            일어일문학과
# 28      유기신소재·파이버공학과
# 29          글로벌미디어학부
# 30           소프트웨어학부
# 31               철학과
# 32       융합특성화자유전공학부
# 33            평생교육학과
# 34            국어국문학과
# 35               수학과
# 36             컴퓨터학부
# 37             스포츠학부
# 38            불어불문학과
# 39     예술창작학부 문예창작전공
# 40               사학과
# 41       정보통계·보험수리학과
# 42              물리학과
# ...

# %% [markdown]
# #### [입학년도, 소속별] -> 연출입건수

# %%
group_in = (primary_lib_in.groupby(["입학년도","소속"])["연출입건수"])
group_in.describe()
# Out:
#                    count        mean         std   min    25%   50%     75%  \
# 입학년도 소속
# 2000 건축학부            5.0   26.800000    8.871302  20.0  22.00  23.0   27.00
#      경영학부            6.0   10.666667   11.360751   1.0   3.50   7.5   12.25
#      국어국문학과          1.0   44.000000         NaN  44.0  44.00  44.0   44.00
#      글로벌미디어학부        3.0  104.333333  104.734585  37.0  44.00  51.0  138.00
#      기계공학부           2.0    8.500000    4.949747   5.0   6.75   8.5   10.25
# ...                  ...         ...         ...   ...    ...   ...     ...
# 2021 행정학부           20.0   28.000000   26.887681   2.0   9.75  19.0   31.50
#      혁신경영학과(계약학과)    1.0    2.000000         NaN   2.0   2.00   2.0    2.00
#      화학공학과          33.0   54.787879  102.818334   1.0  13.00  25.0   66.00
#      화학과            28.0   48.928571   45.558207   2.0  19.50  35.0   60.50
#      회계학과           24.0   40.583333   56.296511   2.0  11.50  27.0   39.00
#
#                      max
# 입학년도 소속
# ...

# %% [markdown]
# #### [입학년도, 소속별] -> 연대출권수

# %%
group_bro = primary_lib_bro.groupby(["입학년도","소속"])["연대출권수"]
group_bro.describe()
# Out:
#                    count       mean        std   min    25%   50%    75%   max
# 입학년도 소속
# 2000 건축학부            5.0  47.600000  10.807405  33.0  44.00  45.0  55.00  61.0
#      경영학부            2.0  10.500000  13.435029   1.0   5.75  10.5  15.25  20.0
#      독어독문학과          2.0   8.000000   7.071068   3.0   5.50   8.0  10.50  13.0
#      법학과             1.0   4.000000        NaN   4.0   4.00   4.0   4.00   4.0
#      유기신소재·파이버공학과    3.0  45.000000  31.320920   9.0  34.50  60.0  63.00  66.0
# ...                  ...        ...        ...   ...    ...   ...    ...   ...
# 2021 평생교육학과          6.0  11.000000  13.221195   1.0   2.25   3.5  21.25  29.0
#      행정학부            6.0  10.000000  15.440207   1.0   2.25   3.5   7.75  41.0
#      화학공학과           7.0   8.428571  11.193110   1.0   2.50   4.0   8.00  33.0
#      화학과             5.0  18.000000  29.453353   1.0   2.00   4.0  13.00  70.0
#      회계학과            9.0  16.111111  22.838807   1.0   3.00   7.0  12.00  69.0
#
# ...

# %%
join_group =pd.merge(primary_lib_in, primary_lib_bro, on = ['입학년도','소속'], how = 'outer')
join_group
# Out:
#          연출입건수  입학년도            소속  연대출권수
# 0          284  2012       글로벌통상학과   97.0
# 1          284  2012       글로벌통상학과    6.0
# 2          284  2012       글로벌통상학과   60.0
# 3          284  2012       글로벌통상학과  177.0
# 4          284  2012       글로벌통상학과   15.0
# ...        ...   ...           ...    ...
# 1361402      2  2021         스포츠학부    2.0
# 1361403      4  2021       미디어경영학과    NaN
# 1361404      9  2007          물리학과    NaN
# 1361405      2  2021  혁신경영학과(계약학과)    NaN
# 1361406      3  2003        독어독문학과    2.0
#
# [1361407 rows x 4 columns]

# %%
join_group = join_group.dropna(how='any') #-> NA하나라도 있으면 지움
join_group =join_group.drop_duplicates(['연출입건수' ,'입학년도','소속'])
join_group =join_group.drop_duplicates(['연대출권수' ,'입학년도','소속'])
join_group['연대출권수'] = join_group['연대출권수'].astype(int)
join_group['연출입건수'] = join_group['연출입건수'].astype(int)
join_group.index = np.arange(len(join_group))

# %%
join_group
# Out:
#      연출입건수  입학년도            소속  연대출권수
# 0      284  2012       글로벌통상학과     97
# 1      278  2015      벤처중소기업학과     10
# 2      694  2012          회계학과      6
# 3      121  2016      의생명시스템학부     39
# 4      713  2014        사회복지학부     50
# ..     ...   ...           ...    ...
# 671     52  2021           수학과      2
# 672     50  2021        독어독문학과     15
# 673     10  2019  복지경영학과(계약학과)      7
# 674     16  2021         스포츠학부      1
# 675      3  2003        독어독문학과      2
#
# [676 rows x 4 columns]

# %%
join_group["연대출권수"][0]
# Out:
# 97

# %%
x_val = []
y_val = []
for idx in range (0 ,len(join_group)):
    x_val.append(join_group["연출입건수"][idx])
    y_val.append(join_group["연대출권수"][idx])

plt.figure(figsize=(5, 5)) #그래프의 크기조절
#plt.xlim([0, 2000])      # X축의 범위: [xmin, xmax]
#plt.ylim([0, 100])     # Y축의 범위: [ymin, ymax]
plt.scatter(x_val,y_val,c='b',alpha= 0.5) #->그래프의 객체 생성
#alpha는 점들의 크기 label은 설명란
#plt.legend(loc = 'upper right') #밑에 Scatter point 박스의 위치를 선정 
plt.xlabel("연출입건수") #--->x축의 제목
plt.ylabel("연대출권수") #--->y축의 제목
plt.title("연출입건수 대비 연대출권수") # ---> 그래프 제목
plt.show()  #-> 그래프를 출력

# %%
plt.figure(figsize=(5, 5)) #그래프의 크기조절
plt.xlim([0, 1000])      # X축의 범위: [xmin, xmax]
plt.ylim([0, 150])     # Y축의 범위: [ymin, ymax]
plt.scatter(x_val,y_val,c='b',alpha= 0.5) #->그래프의 객체 생성
#alpha는 점들의 크기 label은 설명란
#plt.legend(loc = 'upper right') #밑에 Scatter point 박스의 위치를 선정 
plt.xlabel("연출입건수") #--->x축의 제목
plt.ylabel("연대출권수") #--->y축의 제목
plt.title("연출입건수 대비 연대출권수") # ---> 그래프 제목
plt.show()  #-> 그래프를 출력

# %%
# y= 1/4x
x_values = [0,1000]
y_values = [0, 250]

#y = -4x + 2075
x_values2 = [0,1000]
y_values2 = [2175, -1825]



plt.figure(figsize=(5, 5)) #그래프의 크기조절
plt.xlim([0, 1000])      # X축의 범위: [xmin, xmax]
plt.ylim([0, 250])     # Y축의 범위: [ymin, ymax]
plt.plot(x_values,y_values, c='r')
plt.plot(x_values2,y_values2, c='r')
plt.scatter(x_val,y_val,c='b',alpha= 0.5) #->그래프의 객체 생성
#alpha는 점들의 크기 label은 설명란
#plt.legend(loc = 'upper right') #밑에 Scatter point 박스의 위치를 선정 
plt.xlabel("연출입건수") #--->x축의 제목
plt.ylabel("연대출권수") #--->y축의 제목
plt.title("연출입건수 대비 연대출권수") # ---> 그래프 제목
plt.show()  #-> 그래프를 출력

# %%
# y= 1/4x
x_values = [0,1000]
y_values = [0, 250]

#y = -4x + 2175
x_values2 = [0,2175/4]
y_values2 = [2175, 0]



plt.figure(figsize=(20, 5)) #그래프의 크기조절
plt.xlim([0, 1000])      # X축의 범위: [xmin, xmax]
plt.ylim([0, 250])     # Y축의 범위: [ymin, ymax]
plt.plot(x_values,y_values, c='r')
plt.plot(x_values2,y_values2, c='r')
plt.scatter(x_val,y_val,c='b',alpha= 0.5) #->그래프의 객체 생성
#alpha는 점들의 크기 label은 설명란
#plt.legend(loc = 'upper right') #밑에 Scatter point 박스의 위치를 선정 
plt.xlabel("연출입건수") #--->x축의 제목
plt.ylabel("연대출권수") #--->y축의 제목
plt.title("연출입건수 대비 연대출권수") # ---> 그래프 제목
plt.show()  #-> 그래프를 출력

# %%
print(max(x_val),max(y_val))
# Out:
# 2310 295

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 아쉬운대로 clustering 진행

# %%
make_clu = []
for _ in range (0,len(join_group)):
    make_clu.append([])
    
for idx in range (0,len(join_group)):
    if join_group["연출입건수"][idx] < 1000 and join_group["연대출권수"][idx] < 250:
        make_clu[idx].append(join_group["연출입건수"][idx])
        make_clu[idx].append(join_group["연대출권수"][idx])

# %%
while [] in make_clu:    
    make_clu.remove([])
make_clu
# Out:
# [[284, 97],
#  [278, 10],
#  [694, 6],
#  [121, 39],
#  [713, 50],
#  [90, 86],
#  [370, 19],
#  [224, 82],
#  [756, 69],
#  [665, 75],
#  [272, 49],
#  [98, 70],
#  [210, 9],
#  [220, 18],
#  [469, 46],
#  [780, 11],
#  [140, 39],
#  [662, 36],
#  [460, 39],
#  [142, 29],
#  [718, 3],
#  [14, 14],
#  [456, 37],
#  [272, 49],
#  [334, 122],
#  [236, 61],
#  [629, 60],
#  [116, 15],
#  [116, 30],
#  [366, 92],
#  [436, 21],
#  [109, 23],
#  [416, 77],
#  [793, 65],
#  [246, 91],
#  [400, 52],
#  [12, 90],
#  [109, 20],
#  [285, 3],
#  [801, 44],
#  [109, 20],
#  [22, 99],
#  [687, 37],
#  [200, 31],
#  [406, 2],
#  [106, 85],
#  [214, 20],
#  [234, 43],
#  [188, 22],
#  [772, 7],
#  [112, 18],
#  [42, 15],
#  [420, 21],
#  [146, 10],
#  [446, 29],
#  [55, 17],
#  [296, 44],
#  [103, 57],
#  [82, 16],
#  [233, 18],
#  [450, 45],
#  [159, 3],
#  [237, 7],
#  [87, 59],
#  [239, 86],
#  [472, 74],
#  [12, 81],
#  [444, 73],
#  [273, 198],
#  [502, 26],
#  [171, 85],
#  [824, 4],
# ...

# %%
from sklearn.cluster import KMeans
k= 4 # 클러스터의 개수를 미리 지정
kmeans = KMeans(n_clusters = k)
y_pred = kmeans.fit_predict(make_clu)
print("y_pred의 개수 : ",len(y_pred))
print(y_pred[:10])
# Out:
# y_pred의 개수 :  655
# [3 3 1 0 1 0 2 3 1 1]

# %%
index_0 = []
index_1 = []
index_2 = []
index_3 = []

for idx in range (0,len(make_clu)):
    if y_pred[idx] == 0:
        index_0.append(make_clu[idx])
    elif y_pred[idx] == 1:
        index_1.append(make_clu[idx])
    elif y_pred[idx] == 2:
        index_2.append(make_clu[idx])
    else:
        index_3.append(make_clu[idx])
#len(index_0)+len(index_3)+len(index_2)+len(index_1)

# %%
# y= 1/4x
x_values = [0,1000]
y_values = [0, 250]

#y = -4x + 2175
x_values2 = [0,2175/4]
y_values2 = [2175, 0]

plt.figure(figsize=(20, 5)) #그래프의 크기조절
plt.xlim([0, 1000])      # X축의 범위: [xmin, xmax]
plt.ylim([0, 250])     # Y축의 범위: [ymin, ymax]
for lst in index_0:
    plt.scatter(lst[0],lst[1],alpha=0.5, c="g")
for lst in index_1:
    plt.scatter(lst[0],lst[1],alpha=0.5, c="c")
for lst in index_2:
    plt.scatter(lst[0],lst[1],alpha=0.5, c="y")
for lst in index_3:
    plt.scatter(lst[0],lst[1],alpha=0.5, c="m")
#plt.plot(x_values,y_values, c='r')
#plt.plot(x_values2,y_values2, c='r')
plt.xlabel("연출입건수") #--->x축의 제목
plt.ylabel("연대출권수") #--->y축의 제목
plt.title("연출입건수 대비 연대출권수") # ---> 그래프 제목
plt.show()

# %% [markdown]
# # 연대출 권수와 연출입건수 상관관계 구하기

# %%
join_group
# Out:
#      연출입건수  입학년도            소속  연대출권수
# 0      284  2012       글로벌통상학과     97
# 1      278  2015      벤처중소기업학과     10
# 2      694  2012          회계학과      6
# 3      121  2016      의생명시스템학부     39
# 4      713  2014        사회복지학부     50
# ..     ...   ...           ...    ...
# 671     52  2021           수학과      2
# 672     50  2021        독어독문학과     15
# 673     10  2019  복지경영학과(계약학과)      7
# 674     16  2021         스포츠학부      1
# 675      3  2003        독어독문학과      2
#
# [676 rows x 4 columns]

# %%
corr = join_group[['연출입건수','연대출권수']].corr(method = 'pearson')
print(corr)
# Out:
#           연출입건수     연대출권수
# 연출입건수  1.000000  0.106576
# 연대출권수  0.106576  1.000000

# %%
import seaborn as sns
cols_view = ['enter','borrow']
sns.set(font_scale = 1.5)
hm = sns.heatmap(corr.values,
                 cbar = True,
                 annot = True,
                 square = True,
                 fmt = '2f',
                 annot_kws = {'size' : 15},
                 xticklabels = cols_view,
                 yticklabels = cols_view
                )

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.set(style = "whitegrid", context = 'notebook')
sns.pairplot(join_group[['연출입건수','연대출권수']],height = 2.5)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52636 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
